# %%
import pandas as pd

# %%
df = pd.read_csv("salaries_by_college_major.csv")

# %%
df.head(3)
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business

# %%
df.describe()
# Out:
#        Starting Median Salary  Mid-Career Median Salary  \
# count               50.000000                  50.00000
# mean             44310.000000               74786.00000
# std               9360.866217               16088.40386
# min              34000.000000               52000.00000
# 25%              37050.000000               60825.00000
# 50%              40850.000000               72000.00000
# 75%              49875.000000               88750.00000
# max              74300.000000              107000.00000
#
#        Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# count                          50.000000                          50.000000
# mean                        43408.000000                      142766.000000
# std                         12000.779567                       27851.249267
# min                         26700.000000                       96400.000000
# 25%                         34825.000000                      124250.000000
# ...

# %%
len(df)-1
# Out:
# 50

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 6

# %%
df.shape
# Out:
# (51, 6)

# %%
df = df.dropna()

# %%
df.sort_values('Starting Median Salary', ascending = False)
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 43                   Physician Assistant                 74300.0
# 8                   Chemical Engineering                 63200.0
# 12                  Computer Engineering                 61400.0
# 19                Electrical Engineering                 60900.0
# 38                Mechanical Engineering                 57900.0
# 1                  Aerospace Engineering                 57700.0
# 30                Industrial Engineering                 57700.0
# 13                      Computer Science                 55900.0
# 40                               Nursing                 54200.0
# 10                     Civil Engineering                 53900.0
# 14                          Construction                 53700.0
# 44                               Physics                 50300.0
# 17                             Economics                 50100.0
# ...

# %%
df.loc[df['Starting Median Salary'].idxmax()]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                             74300
# Mid-Career Median Salary                           91700
# Mid-Career 10th Percentile Salary                  66400
# Mid-Career 90th Percentile Salary                 124000
# Group                                               STEM
# Name: 43, dtype: object

# %%
df.loc[df['Mid-Career Median Salary'].idxmax()]
# Out:
# Undergraduate Major                  Chemical Engineering
# Starting Median Salary                              63200
# Mid-Career Median Salary                           107000
# Mid-Career 10th Percentile Salary                   71900
# Mid-Career 90th Percentile Salary                  194000
# Group                                                STEM
# Name: 8, dtype: object

# %%
df.loc[df['Mid-Career Median Salary'].idxmin()]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                   34900
# Mid-Career Median Salary                 52000
# Mid-Career 10th Percentile Salary        29300
# Mid-Career 90th Percentile Salary       102000
# Group                                     HASS
# Name: 18, dtype: object

# %%
sp_col = df['Mid-Career 90th Percentile Salary']-df['Mid-Career 10th Percentile Salary']

# %%
type(sp_col)
# Out:
# pandas.core.series.Series

# %%
df.insert(1,"spread", sp_col)

# %%
df.head(3)
# Out:
#      Undergraduate Major    spread  Starting Median Salary  \
# 0             Accounting  109800.0                 46000.0
# 1  Aerospace Engineering   96700.0                 57700.0
# 2            Agriculture  113700.0                 42600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business

# %%
df.sort_values("spread")
# Out:
#                      Undergraduate Major    spread  Starting Median Salary  \
# 40                               Nursing   50700.0                 54200.0
# 43                   Physician Assistant   57600.0                 74300.0
# 41                             Nutrition   65300.0                 39900.0
# 49                               Spanish   65400.0                 34000.0
# 27            Health Care Administration   66400.0                 38800.0
# 47                              Religion   66700.0                 34100.0
# 23                              Forestry   70000.0                 39100.0
# 32                       Interior Design   71300.0                 36100.0
# 18                             Education   72700.0                 34900.0
# 15                      Criminal Justice   74800.0                 35000.0
# 26                        Graphic Design   76000.0                 35700.0
# ...

# %%
highest_potential = df.sort_values('Mid-Career 90th Percentile Salary', ascending=False)
highest_potential[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                           210000.0
# 22               Finance                           195000.0
# 8   Chemical Engineering                           194000.0
# 37                  Math                           183000.0
# 44               Physics                           178000.0

# %%
highest_spread = df.sort_values('spread', ascending=False)
highest_spread[['Undergraduate Major', 'spread']].head()
# Out:
#    Undergraduate Major    spread
# 17           Economics  159400.0
# 22             Finance  147800.0
# 37                Math  137800.0
# 36           Marketing  132900.0
# 42          Philosophy  132500.0

# %%
df_group = df.groupby('Group')

# %%
df_group.describe()
# Out:
#          spread                                                           \
#           count           mean           std      min      25%       50%
# Group
# Business   12.0  103958.333333  33138.153192  50700.0  81550.0  109000.0
# HASS       22.0   95218.181818  20394.832127  65300.0  75100.0   97900.0
# STEM       16.0  101600.000000  18356.724472  57600.0  96500.0   99000.0
#
#                              Starting Median Salary                ...  \
#                75%       max                  count          mean  ...
# Group                                                              ...
# Business  119250.0  159400.0                   12.0  44633.333333  ...
# HASS      107125.0  132500.0                   22.0  37186.363636  ...
# STEM      112225.0  137800.0                   16.0  53862.500000  ...
#
#          Mid-Career 10th Percentile Salary           \
#                                        75%      max
# Group
# ...

# %%
df_group.mean()
# Out:
#                  spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business  103958.333333            44633.333333              75083.333333
# HASS       95218.181818            37186.363636              62968.181818
# STEM      101600.000000            53862.500000              90812.500000
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                       43566.666667                      147525.000000
# HASS                           34145.454545                      129363.636364
# STEM                           56025.000000                      157625.000000

# %%
df_group.std()
# Out:
#                 spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business  33138.153192             5706.349467              12450.544591
# HASS      20394.832127             2255.637478               9092.350860
# STEM      18356.724472             9132.204918              11714.826788
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                        6889.693664                       35799.165176
# HASS                            3856.191962                       22436.843540
# STEM                           10916.928750                       19293.781382

# %%
df_group.mean()/df_group.std()
# Out:
#             spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business  3.137119                7.821696                  6.030526
# HASS      4.668741               16.485966                  6.925402
# STEM      5.534756                5.898083                  7.751929
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                           6.323455                           4.120906
# HASS                               8.854708                           5.765679
# STEM                               5.131938                           8.169731

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df_group.mean()
# Out:
#              spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business 103,958.33               44,633.33                 75,083.33
# HASS      95,218.18               37,186.36                 62,968.18
# STEM     101,600.00               53,862.50                 90,812.50
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                          43,566.67                         147,525.00
# HASS                              34,145.45                         129,363.64
# STEM                              56,025.00                         157,625.00
