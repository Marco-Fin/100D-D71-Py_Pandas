# %% [markdown]
# ## Intro to **Pandas**

# %%
import pandas as pd
import numpy as np

# %%
dates = pd.date_range("20200101", periods=500)

# %% [markdown]
# ***CREATION***

# %%
df = pd.DataFrame(np.random.randn(500,5), index = dates, columns = ['Ativo1','Ativo2','Ativo3', 'Ativo4','Ativo5'])

# %%
df
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2020-01-01  0.505689 -1.590556  0.794761  0.360031  1.587777
# 2020-01-02 -1.228261  1.112206 -2.744794  0.979471  0.930336
# 2020-01-03 -0.550239  1.277771  0.791220  0.029177  0.063592
# 2020-01-04 -0.475582 -1.025496 -0.861320 -0.443509 -1.504503
# 2020-01-05 -0.180217 -0.683909 -0.036566 -0.972426 -2.352794
# ...              ...       ...       ...       ...       ...
# 2021-05-10 -0.244123 -1.026962 -1.750563  0.978197  0.806823
# 2021-05-11 -1.766235 -0.151846 -1.229213  0.487776 -0.398046
# 2021-05-12  0.445689  0.591225 -1.764007  0.438313  0.599920
# 2021-05-13 -2.278970 -0.731026  0.339852 -1.019133  0.450602
# 2021-05-14  1.399711  1.146138  0.013119  0.054667 -0.852683
#
# [500 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Ativo1', 'Ativo2', 'Ativo3', 'Ativo4', 'Ativo5'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-05-05', '2021-05-06', '2021-05-07', '2021-05-08',
#                '2021-05-09', '2021-05-10', '2021-05-11', '2021-05-12',
#                '2021-05-13', '2021-05-14'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2020-01-01  0.505689 -1.590556  0.794761  0.360031  1.587777
# 2020-01-02 -1.228261  1.112206 -2.744794  0.979471  0.930336
# 2020-01-03 -0.550239  1.277771  0.791220  0.029177  0.063592
# 2020-01-04 -0.475582 -1.025496 -0.861320 -0.443509 -1.504503
# 2020-01-05 -0.180217 -0.683909 -0.036566 -0.972426 -2.352794
# ...              ...       ...       ...       ...       ...
# 2021-05-10 -0.244123 -1.026962 -1.750563  0.978197  0.806823
# 2021-05-11 -1.766235 -0.151846 -1.229213  0.487776 -0.398046
# 2021-05-12  0.445689  0.591225 -1.764007  0.438313  0.599920
# 2021-05-13 -2.278970 -0.731026  0.339852 -1.019133  0.450602
# 2021-05-14  1.399711  1.146138  0.013119  0.054667 -0.852683
#
# [500 rows x 5 columns]>

# %%
len(df)
# Out:
# 500

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(3)
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2020-01-01  0.505689 -1.590556  0.794761  0.360031  1.587777
# 2020-01-02 -1.228261  1.112206 -2.744794  0.979471  0.930336
# 2020-01-03 -0.550239  1.277771  0.791220  0.029177  0.063592

# %% [markdown]
# ###

# %%
df.tail(3)
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2021-05-12  0.445689  0.591225 -1.764007  0.438313  0.599920
# 2021-05-13 -2.278970 -0.731026  0.339852 -1.019133  0.450602
# 2021-05-14  1.399711  1.146138  0.013119  0.054667 -0.852683

# %% [markdown]
# ***to numpy***

# %%
my_ndarray = df.to_numpy()

# %%
my_ndarray
# Out:
# array([[ 0.50568879, -1.59055631,  0.7947613 ,  0.36003139,  1.58777726],
#        [-1.2282611 ,  1.11220645, -2.74479375,  0.9794706 ,  0.93033638],
#        [-0.55023888,  1.27777141,  0.79121995,  0.02917724,  0.06359151],
#        ...,
#        [ 0.44568931,  0.59122456, -1.76400728,  0.43831265,  0.59991978],
#        [-2.27896993, -0.73102647,  0.33985246, -1.01913296,  0.45060246],
#        [ 1.39971073,  1.1461378 ,  0.01311927,  0.05466745, -0.85268328]])

# %%
type(my_ndarray)
# Out:
# numpy.ndarray

# %%
my_ndarray.shape
# Out:
# (500, 5)

# %% [markdown]
# ***Transpose***

# %%
df.T
# Out:
#         2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05  \
# Ativo1    0.505689   -1.228261   -0.550239   -0.475582   -0.180217
# Ativo2   -1.590556    1.112206    1.277771   -1.025496   -0.683909
# Ativo3    0.794761   -2.744794    0.791220   -0.861320   -0.036566
# Ativo4    0.360031    0.979471    0.029177   -0.443509   -0.972426
# Ativo5    1.587777    0.930336    0.063592   -1.504503   -2.352794
#
#         2020-01-06  2020-01-07  2020-01-08  2020-01-09  2020-01-10  ...  \
# Ativo1   -0.273464   -0.303196   -1.720888   -0.659123   -1.018316  ...
# Ativo2    0.697212   -0.173053   -1.020146   -0.110233   -0.664281  ...
# Ativo3   -1.410417   -0.469413   -0.194344   -0.732102    0.361856  ...
# Ativo4   -0.098117    1.562082    2.240090   -0.287366    0.852608  ...
# Ativo5    0.740572    0.472406   -0.509628   -0.686601    0.410297  ...
#
#         2021-05-05  2021-05-06  2021-05-07  2021-05-08  2021-05-09  \
# ...

# %%
my_ndarray.T
# Out:
# array([[ 0.50568879, -1.2282611 , -0.55023888, ...,  0.44568931,
#         -2.27896993,  1.39971073],
#        [-1.59055631,  1.11220645,  1.27777141, ...,  0.59122456,
#         -0.73102647,  1.1461378 ],
#        [ 0.7947613 , -2.74479375,  0.79121995, ..., -1.76400728,
#          0.33985246,  0.01311927],
#        [ 0.36003139,  0.9794706 ,  0.02917724, ...,  0.43831265,
#         -1.01913296,  0.05466745],
#        [ 1.58777726,  0.93033638,  0.06359151, ...,  0.59991978,
#          0.45060246, -0.85268328]])

# %% [markdown]
# ***Sorting***

# %%
## Sort by an index
df.sort_index(axis=0, ascending = False)
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2021-05-14  1.399711  1.146138  0.013119  0.054667 -0.852683
# 2021-05-13 -2.278970 -0.731026  0.339852 -1.019133  0.450602
# 2021-05-12  0.445689  0.591225 -1.764007  0.438313  0.599920
# 2021-05-11 -1.766235 -0.151846 -1.229213  0.487776 -0.398046
# 2021-05-10 -0.244123 -1.026962 -1.750563  0.978197  0.806823
# ...              ...       ...       ...       ...       ...
# 2020-01-05 -0.180217 -0.683909 -0.036566 -0.972426 -2.352794
# 2020-01-04 -0.475582 -1.025496 -0.861320 -0.443509 -1.504503
# 2020-01-03 -0.550239  1.277771  0.791220  0.029177  0.063592
# 2020-01-02 -1.228261  1.112206 -2.744794  0.979471  0.930336
# 2020-01-01  0.505689 -1.590556  0.794761  0.360031  1.587777
#
# [500 rows x 5 columns]

# %%
## Sort by Cols
df.sort_values(by="Ativo5")
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2020-06-12 -1.617737 -0.178414  1.083407 -1.142467 -3.006664
# 2020-02-29 -0.348866 -0.157603  0.286441  0.195326 -2.630634
# 2020-12-31  0.055625  0.283744  0.161322  0.388331 -2.381591
# 2020-01-05 -0.180217 -0.683909 -0.036566 -0.972426 -2.352794
# 2021-02-20  1.242231 -1.040994  0.295221 -1.182967 -2.300941
# ...              ...       ...       ...       ...       ...
# 2020-07-23 -1.122428 -1.624351 -0.312545 -0.711079  2.257873
# 2020-12-07  1.120170  1.151120 -0.251068 -0.712597  2.258391
# 2020-07-15 -1.609459 -2.726316 -0.994924  0.678338  2.332505
# 2020-08-13  0.700607 -1.159816  1.133733  0.870618  2.342813
# 2020-04-14 -0.783489 -0.929891 -1.607202 -0.254328  2.678989
#
# [500 rows x 5 columns]

# %% [markdown]
# # **Selection** #
# **iloc, loc, iat, at**

# %%
l1 = df['Ativo1']
l1
# Out:
# 2020-01-01    0.505689
# 2020-01-02   -1.228261
# 2020-01-03   -0.550239
# 2020-01-04   -0.475582
# 2020-01-05   -0.180217
#                 ...
# 2021-05-10   -0.244123
# 2021-05-11   -1.766235
# 2021-05-12    0.445689
# 2021-05-13   -2.278970
# 2021-05-14    1.399711
# Freq: D, Name: Ativo1, Length: 500, dtype: float64

# %%
type(l1)
# Out:
# pandas.core.series.Series

# %%
l2 = df[0:10]
l2
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2020-01-01  0.505689 -1.590556  0.794761  0.360031  1.587777
# 2020-01-02 -1.228261  1.112206 -2.744794  0.979471  0.930336
# 2020-01-03 -0.550239  1.277771  0.791220  0.029177  0.063592
# 2020-01-04 -0.475582 -1.025496 -0.861320 -0.443509 -1.504503
# 2020-01-05 -0.180217 -0.683909 -0.036566 -0.972426 -2.352794
# 2020-01-06 -0.273464  0.697212 -1.410417 -0.098117  0.740572
# 2020-01-07 -0.303196 -0.173053 -0.469413  1.562082  0.472406
# 2020-01-08 -1.720888 -1.020146 -0.194344  2.240090 -0.509628
# 2020-01-09 -0.659123 -0.110233 -0.732102 -0.287366 -0.686601
# 2020-01-10 -1.018316 -0.664281  0.361856  0.852608  0.410297

# %%
type(l2)
# Out:
# pandas.core.frame.DataFrame

# %%
l3 = df["20210101":]
l3
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2021-01-01 -0.294521 -1.667926  0.442489 -0.313368 -2.186535
# 2021-01-02  0.115718  0.130320 -0.457024 -0.875998  1.328420
# 2021-01-03 -1.185714 -0.635480  1.369047 -0.660120 -0.538127
# 2021-01-04  0.582503  1.323177 -0.357378 -0.923750  1.014242
# 2021-01-05  0.484790  0.675426  0.698835  0.604440 -0.013396
# ...              ...       ...       ...       ...       ...
# 2021-05-10 -0.244123 -1.026962 -1.750563  0.978197  0.806823
# 2021-05-11 -1.766235 -0.151846 -1.229213  0.487776 -0.398046
# 2021-05-12  0.445689  0.591225 -1.764007  0.438313  0.599920
# 2021-05-13 -2.278970 -0.731026  0.339852 -1.019133  0.450602
# 2021-05-14  1.399711  1.146138  0.013119  0.054667 -0.852683
#
# [134 rows x 5 columns]

# %%
# This is an intentional error
df[20]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\usuario\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 20
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-5a5104ad4ec7> in <module>
# ...

# %%
# This is an intentional error
df['20210101']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\usuario\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '20210101'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # LOC - Lables

# %%
df.loc[dates[10]]
# Out:
# Ativo1   -1.809809
# Ativo2   -2.791317
# Ativo3    0.071543
# Ativo4    1.377084
# Ativo5    0.040155
# Name: 2020-01-11 00:00:00, dtype: float64

# %%
df.loc['20210115']
# Out:
# Ativo1   -1.850886
# Ativo2   -0.478662
# Ativo3   -0.680900
# Ativo4   -1.462709
# Ativo5    1.653265
# Name: 2021-01-15 00:00:00, dtype: float64

# %%
df.loc[:, "Ativo1"]
# Out:
# 2020-01-01    0.505689
# 2020-01-02   -1.228261
# 2020-01-03   -0.550239
# 2020-01-04   -0.475582
# 2020-01-05   -0.180217
#                 ...
# 2021-05-10   -0.244123
# 2021-05-11   -1.766235
# 2021-05-12    0.445689
# 2021-05-13   -2.278970
# 2021-05-14    1.399711
# Freq: D, Name: Ativo1, Length: 500, dtype: float64

# %%
df.loc[:, ["Ativo1","Ativo2"]]
# Out:
#               Ativo1    Ativo2
# 2020-01-01  0.505689 -1.590556
# 2020-01-02 -1.228261  1.112206
# 2020-01-03 -0.550239  1.277771
# 2020-01-04 -0.475582 -1.025496
# 2020-01-05 -0.180217 -0.683909
# ...              ...       ...
# 2021-05-10 -0.244123 -1.026962
# 2021-05-11 -1.766235 -0.151846
# 2021-05-12  0.445689  0.591225
# 2021-05-13 -2.278970 -0.731026
# 2021-05-14  1.399711  1.146138
#
# [500 rows x 2 columns]

# %%
df.loc[dates[100]:dates[200], ["Ativo1","Ativo2"]]
# Out:
#               Ativo1    Ativo2
# 2020-04-10 -0.079220  0.101572
# 2020-04-11 -0.470833  0.782068
# 2020-04-12 -1.248924 -0.273869
# 2020-04-13 -0.850502  1.666181
# 2020-04-14 -0.783489 -0.929891
# ...              ...       ...
# 2020-07-15 -1.609459 -2.726316
# 2020-07-16  0.141145 -1.102958
# 2020-07-17 -0.907910 -1.754084
# 2020-07-18 -0.636103  0.464894
# 2020-07-19  0.191043  0.453713
#
# [101 rows x 2 columns]

# %%
df.loc[dates[100:200], ["Ativo1","Ativo2"]]
# Out:
#               Ativo1    Ativo2
# 2020-04-10 -0.079220  0.101572
# 2020-04-11 -0.470833  0.782068
# 2020-04-12 -1.248924 -0.273869
# 2020-04-13 -0.850502  1.666181
# 2020-04-14 -0.783489 -0.929891
# ...              ...       ...
# 2020-07-14 -0.459521 -0.352249
# 2020-07-15 -1.609459 -2.726316
# 2020-07-16  0.141145 -1.102958
# 2020-07-17 -0.907910 -1.754084
# 2020-07-18 -0.636103  0.464894
#
# [100 rows x 2 columns]

# %% [markdown]
# # ILOC - Position

# %%
df.iloc[300]
# Out:
# Ativo1   -0.500614
# Ativo2    0.141868
# Ativo3    0.077901
# Ativo4    0.071469
# Ativo5   -0.849490
# Name: 2020-10-27 00:00:00, dtype: float64

# %%
df.iloc[300:400]
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2020-10-27 -0.500614  0.141868  0.077901  0.071469 -0.849490
# 2020-10-28 -2.169446  0.977153 -0.389015  0.762703 -0.468548
# 2020-10-29 -0.716935  0.267897  0.014132 -0.525526 -1.206848
# 2020-10-30 -0.514412  0.792880 -1.279768  0.058327 -2.112759
# 2020-10-31  0.196338  2.007081 -0.594211  1.711336 -1.300724
# ...              ...       ...       ...       ...       ...
# 2021-01-30  0.091932 -0.440305  1.499738 -2.540935  0.032593
# 2021-01-31  0.432215  0.735842  1.477556 -0.352826  0.248620
# 2021-02-01 -1.654463  0.813337 -0.560728 -0.221491 -0.697923
# 2021-02-02  0.789044  0.142800 -2.031974 -0.927234  0.124772
# 2021-02-03  1.472360  0.440028  0.617327  0.225308  0.670984
#
# [100 rows x 5 columns]

# %%
df.iloc[300:400, 0:2]
# Out:
#               Ativo1    Ativo2
# 2020-10-27 -0.500614  0.141868
# 2020-10-28 -2.169446  0.977153
# 2020-10-29 -0.716935  0.267897
# 2020-10-30 -0.514412  0.792880
# 2020-10-31  0.196338  2.007081
# ...              ...       ...
# 2021-01-30  0.091932 -0.440305
# 2021-01-31  0.432215  0.735842
# 2021-02-01 -1.654463  0.813337
# 2021-02-02  0.789044  0.142800
# 2021-02-03  1.472360  0.440028
#
# [100 rows x 2 columns]

# %%
df.iloc[[300,305,355], [0,2,4]]
# Out:
#               Ativo1    Ativo3    Ativo5
# 2020-10-27 -0.500614  0.077901 -0.849490
# 2020-11-01 -0.146901 -0.429022  0.639727
# 2020-12-21 -1.459295  1.012497  1.058897

# %% [markdown]
# ## THE BEST FOR LAST PART 1
# ## BOOLEAN Conditions

# %%
df[df["Ativo1"] > 0]
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2020-01-01  0.505689 -1.590556  0.794761  0.360031  1.587777
# 2020-01-15  1.505447  0.578586 -0.673950  0.284067  0.378286
# 2020-01-17  0.268572 -0.577339  1.425419 -0.140042 -1.133073
# 2020-01-19  0.590467 -0.626918 -0.716044  1.415840 -1.631041
# 2020-01-20  0.874275 -0.731333 -0.154304  0.400361 -0.814631
# ...              ...       ...       ...       ...       ...
# 2021-05-05  0.527720 -0.281286 -1.485242 -0.249578 -1.000315
# 2021-05-06  0.944541  0.589084 -0.285704 -0.434900  0.152876
# 2021-05-09  0.388098  0.675133 -0.144773  0.128709 -0.597650
# 2021-05-12  0.445689  0.591225 -1.764007  0.438313  0.599920
# 2021-05-14  1.399711  1.146138  0.013119  0.054667 -0.852683
#
# [240 rows x 5 columns]

# %%
df[df>0]
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2020-01-01  0.505689       NaN  0.794761  0.360031  1.587777
# 2020-01-02       NaN  1.112206       NaN  0.979471  0.930336
# 2020-01-03       NaN  1.277771  0.791220  0.029177  0.063592
# 2020-01-04       NaN       NaN       NaN       NaN       NaN
# 2020-01-05       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...
# 2021-05-10       NaN       NaN       NaN  0.978197  0.806823
# 2021-05-11       NaN       NaN       NaN  0.487776       NaN
# 2021-05-12  0.445689  0.591225       NaN  0.438313  0.599920
# 2021-05-13       NaN       NaN  0.339852       NaN  0.450602
# 2021-05-14  1.399711  1.146138  0.013119  0.054667       NaN
#
# [500 rows x 5 columns]

# %%
df
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5
# 2020-01-01  0.505689 -1.590556  0.794761  0.360031  1.587777
# 2020-01-02 -1.228261  1.112206 -2.744794  0.979471  0.930336
# 2020-01-03 -0.550239  1.277771  0.791220  0.029177  0.063592
# 2020-01-04 -0.475582 -1.025496 -0.861320 -0.443509 -1.504503
# 2020-01-05 -0.180217 -0.683909 -0.036566 -0.972426 -2.352794
# ...              ...       ...       ...       ...       ...
# 2021-05-10 -0.244123 -1.026962 -1.750563  0.978197  0.806823
# 2021-05-11 -1.766235 -0.151846 -1.229213  0.487776 -0.398046
# 2021-05-12  0.445689  0.591225 -1.764007  0.438313  0.599920
# 2021-05-13 -2.278970 -0.731026  0.339852 -1.019133  0.450602
# 2021-05-14  1.399711  1.146138  0.013119  0.054667 -0.852683
#
# [500 rows x 5 columns]

# %% [markdown]
# ## Some Ploting

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.cumsum().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Column operations

# %%
df['Ativo6'] = df['Ativo1']+df['Ativo2'] - df['Ativo3']

# %%
df
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5    Ativo6
# 2020-01-01  0.505689 -1.590556  0.794761  0.360031  1.587777 -1.879629
# 2020-01-02 -1.228261  1.112206 -2.744794  0.979471  0.930336  2.628739
# 2020-01-03 -0.550239  1.277771  0.791220  0.029177  0.063592 -0.063687
# 2020-01-04 -0.475582 -1.025496 -0.861320 -0.443509 -1.504503 -0.639758
# 2020-01-05 -0.180217 -0.683909 -0.036566 -0.972426 -2.352794 -0.827561
# ...              ...       ...       ...       ...       ...       ...
# 2021-05-10 -0.244123 -1.026962 -1.750563  0.978197  0.806823  0.479478
# 2021-05-11 -1.766235 -0.151846 -1.229213  0.487776 -0.398046 -0.688869
# 2021-05-12  0.445689  0.591225 -1.764007  0.438313  0.599920  2.800921
# 2021-05-13 -2.278970 -0.731026  0.339852 -1.019133  0.450602 -3.349849
# 2021-05-14  1.399711  1.146138  0.013119  0.054667 -0.852683  2.532729
#
# [500 rows x 6 columns]

# %%
df['Ativo7'] = 1.1

# %%
df
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5    Ativo6  Ativo7
# 2020-01-01  0.505689 -1.590556  0.794761  0.360031  1.587777 -1.879629     1.1
# 2020-01-02 -1.228261  1.112206 -2.744794  0.979471  0.930336  2.628739     1.1
# 2020-01-03 -0.550239  1.277771  0.791220  0.029177  0.063592 -0.063687     1.1
# 2020-01-04 -0.475582 -1.025496 -0.861320 -0.443509 -1.504503 -0.639758     1.1
# 2020-01-05 -0.180217 -0.683909 -0.036566 -0.972426 -2.352794 -0.827561     1.1
# ...              ...       ...       ...       ...       ...       ...     ...
# 2021-05-10 -0.244123 -1.026962 -1.750563  0.978197  0.806823  0.479478     1.1
# 2021-05-11 -1.766235 -0.151846 -1.229213  0.487776 -0.398046 -0.688869     1.1
# 2021-05-12  0.445689  0.591225 -1.764007  0.438313  0.599920  2.800921     1.1
# 2021-05-13 -2.278970 -0.731026  0.339852 -1.019133  0.450602 -3.349849     1.1
# 2021-05-14  1.399711  1.146138  0.013119  0.054667 -0.852683  2.532729     1.1
#
# [500 rows x 7 columns]

# %%
df['Ativo8'] = 1000

# %%
df
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5    Ativo6  \
# 2020-01-01  0.505689 -1.590556  0.794761  0.360031  1.587777 -1.879629
# 2020-01-02 -1.228261  1.112206 -2.744794  0.979471  0.930336  2.628739
# 2020-01-03 -0.550239  1.277771  0.791220  0.029177  0.063592 -0.063687
# 2020-01-04 -0.475582 -1.025496 -0.861320 -0.443509 -1.504503 -0.639758
# 2020-01-05 -0.180217 -0.683909 -0.036566 -0.972426 -2.352794 -0.827561
# ...              ...       ...       ...       ...       ...       ...
# 2021-05-10 -0.244123 -1.026962 -1.750563  0.978197  0.806823  0.479478
# 2021-05-11 -1.766235 -0.151846 -1.229213  0.487776 -0.398046 -0.688869
# 2021-05-12  0.445689  0.591225 -1.764007  0.438313  0.599920  2.800921
# 2021-05-13 -2.278970 -0.731026  0.339852 -1.019133  0.450602 -3.349849
# 2021-05-14  1.399711  1.146138  0.013119  0.054667 -0.852683  2.532729
#
#             Ativo7  Ativo8
# 2020-01-01     1.1    1000
# 2020-01-02     1.1    1000
# 2020-01-03     1.1    1000
# ...

# %%
del df['Ativo8']

# %%
df
# Out:
#               Ativo1    Ativo2    Ativo3    Ativo4    Ativo5    Ativo6  Ativo7
# 2020-01-01  0.505689 -1.590556  0.794761  0.360031  1.587777 -1.879629     1.1
# 2020-01-02 -1.228261  1.112206 -2.744794  0.979471  0.930336  2.628739     1.1
# 2020-01-03 -0.550239  1.277771  0.791220  0.029177  0.063592 -0.063687     1.1
# 2020-01-04 -0.475582 -1.025496 -0.861320 -0.443509 -1.504503 -0.639758     1.1
# 2020-01-05 -0.180217 -0.683909 -0.036566 -0.972426 -2.352794 -0.827561     1.1
# ...              ...       ...       ...       ...       ...       ...     ...
# 2021-05-10 -0.244123 -1.026962 -1.750563  0.978197  0.806823  0.479478     1.1
# 2021-05-11 -1.766235 -0.151846 -1.229213  0.487776 -0.398046 -0.688869     1.1
# 2021-05-12  0.445689  0.591225 -1.764007  0.438313  0.599920  2.800921     1.1
# 2021-05-13 -2.278970 -0.731026  0.339852 -1.019133  0.450602 -3.349849     1.1
# 2021-05-14  1.399711  1.146138  0.013119  0.054667 -0.852683  2.532729     1.1
#
# [500 rows x 7 columns]
